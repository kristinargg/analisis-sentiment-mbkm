# %% [markdown]
# # Klasifikasi Opini Pengguna Media Sosial Twitter Terhadap Program Kampus Merdeka Dengan Metode Naive Bayes
#
# Dataset yang digunakan dalam analisis ini merupakan data postingan yang berisi tentang program kampus merdeka dengan 3 label (positif & negatif) yang telah Saya simpan dalam format .

# %% [markdown]
# # 1. Install & Import Library & Dependencies

# %%
# pip install imblearn

# %%
# pip install sastrawi

# %%
import nltk
import matplotlib.pyplot as plt
import random
import pandas as pd
import numpy as np
import re
import itertools
import string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('punkt')
nltk.download('stopwords')

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # 2. Import data tweet Program Kampus Merdeka

# %%
df_tweets = pd.read_excel('dataset.xlsx')
df_tweets.isna().sum()
# Out:
# id       0
# Tweet    0
# Label    0
# dtype: int64

# %%
df_tweets
# Out:
#       id                                              Tweet      Label
# 0      1  @alahsokap ya kan gua bilang tergantung kampus...  Mendukung
# 1      2  @fraijours @PeachPluffy Kak saya juga mengikut...  Mendukung
# 2      3  @miegacoans @convomfs 3. Kalau masih kupu" jug...  Mendukung
# 3      4  @uknowrav Diantara sekian banyak program kampu...  Mendukung
# 4      5  tp ada saat dimana gua bersyukur banget dan be...  Mendukung
# ..   ...                                                ...        ...
# 852  853  @alandakariza Indonesian International Student...  Mendukung
# 853  854  Mendikbudristek: Mahasiswa Didorong Ikut Progr...  Mendukung
# 854  855  Maxy Academy Resmi Jadi Official Partner Kampu...  Mendukung
# 855  856  Beberapa di antaranya adalah program Kampus Me...  Mendukung
# 856  857  [cm]  guys program kampus merdeka tuh semuanya...  Mendukung
#
# [857 rows x 3 columns]

# %% [markdown]
# # 3. Delete duplicate & unused column

# %%
df_tweets.drop(df_tweets.filter(regex="Unname"),axis=1, inplace=True)
df_tweets
# Out:
#       id                                              Tweet      Label
# 0      1  @alahsokap ya kan gua bilang tergantung kampus...  Mendukung
# 1      2  @fraijours @PeachPluffy Kak saya juga mengikut...  Mendukung
# 2      3  @miegacoans @convomfs 3. Kalau masih kupu" jug...  Mendukung
# 3      4  @uknowrav Diantara sekian banyak program kampu...  Mendukung
# 4      5  tp ada saat dimana gua bersyukur banget dan be...  Mendukung
# ..   ...                                                ...        ...
# 852  853  @alandakariza Indonesian International Student...  Mendukung
# 853  854  Mendikbudristek: Mahasiswa Didorong Ikut Progr...  Mendukung
# 854  855  Maxy Academy Resmi Jadi Official Partner Kampu...  Mendukung
# 855  856  Beberapa di antaranya adalah program Kampus Me...  Mendukung
# 856  857  [cm]  guys program kampus merdeka tuh semuanya...  Mendukung
#
# [857 rows x 3 columns]

# %% [markdown]
# # 4. Create preprocessing function

# %%
sw = stopwords.words('indonesian')

# %%
# import pandas as pd
# import re
# from nltk.tokenize import word_tokenize
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# from nltk.corpus import stopwords as sw

# Membaca file CSV
# df_tweets = pd.read_csv('tweets.csv')

# Fungsi untuk melakukan preprocessing
def word_tokenize_wrapper(text):
    return word_tokenize(text)

def remove_tweet_special(text):
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"").replace('USERNAME', "").replace('-', " ").replace(',', " ")
    text = text.encode('ascii', 'replace').decode('ascii')
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    return text.replace("http://", " ").replace("https://", " ")
                
def remove_number(text):
    return  re.sub(r"\d+", "", str(text))
 
def remove_punctuation(text):
    import string
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

 
def stopwords(text, additional_sw=['wkwkw', 'wkwkwkkw', 'ohhh', 'ohhh', 'anjirrrr', 'aaaakk' 'wkwk', 'wkwkwk', 'nder', 'cm', 'shopee', 'cmiiw', 'wkwkwkwkwk', 'gaess', 'huhu', 'xixixi', 'wkwkwkw', 'skrg',  "ambil", "banget", "capek", "sempat", "emang", "susah", 'cont','drpd', 'anjit', 'wkwk', 'lhokseumawe', "woi", "ignya", "anjir", "abis", "Lhokseumawe", "sebagainya", 'dsbnya']):
    sw2 = set(sw + additional_sw)
    text = [word.lower() for word in text if word.lower() not in sw2]
    return " ".join(text)
    
def remove_whitespace_LT(text):
    return text.strip()
 
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

 
def preprocess_tweet(tweet):
    tweet = tweet.lower()
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    output = stemmer.stem(tweet) 
    return output


def preprocess_text(df_tweets):
    df_tweets['rm_special'] = df_tweets['Tweet'].apply(remove_tweet_special)
    df_tweets['remove_number'] = df_tweets['rm_special'].apply(remove_number)
    df_tweets['remove_p'] = df_tweets['remove_number'].apply(remove_punctuation)
    df_tweets['tokens'] = df_tweets['remove_p'].apply(word_tokenize_wrapper)
    df_tweets['stopword'] = df_tweets['tokens'].apply(stopwords)
    df_tweets['remove_whitespace_LT'] = df_tweets['stopword'].apply(remove_whitespace_LT)
    df_tweets['remove_whitespace_multiple'] = df_tweets['remove_whitespace_LT'].apply(remove_whitespace_multiple)
    df_tweets['preprocess_tweet'] = df_tweets['remove_whitespace_multiple'].apply(preprocess_tweet)
    return df_tweets

# %% [markdown]
# # 5. Text preprocessing

# %%
# Melakukan Preprocessing
df_preprocessed = preprocess_text(df_tweets)

# Menyimpan data preprocessing ke file CSV
df_preprocessed.to_csv('preprocessed.csv', index=False)

# %%
df_preprocessed
# Out:
#       id                                              Tweet      Label  \
# 0      1  @alahsokap ya kan gua bilang tergantung kampus...  Mendukung
# 1      2  @fraijours @PeachPluffy Kak saya juga mengikut...  Mendukung
# 2      3  @miegacoans @convomfs 3. Kalau masih kupu" jug...  Mendukung
# 3      4  @uknowrav Diantara sekian banyak program kampu...  Mendukung
# 4      5  tp ada saat dimana gua bersyukur banget dan be...  Mendukung
# ..   ...                                                ...        ...
# 852  853  @alandakariza Indonesian International Student...  Mendukung
# 853  854  Mendikbudristek: Mahasiswa Didorong Ikut Progr...  Mendukung
# 854  855  Maxy Academy Resmi Jadi Official Partner Kampu...  Mendukung
# 855  856  Beberapa di antaranya adalah program Kampus Me...  Mendukung
# 856  857  [cm]  guys program kampus merdeka tuh semuanya...  Mendukung
#
#                                             rm_special  \
# 0    ya kan gua bilang tergantung kampus pas awal" ...
# 1    Kak saya juga mengikuti program Bangkit dan sa...
# 2    3. Kalau masih kupu" juga deket ama dosen haha...
# 3    Diantara sekian banyak program kampus merdeka ...
# 4    tp ada saat dimana gua bersyukur banget dan be...
# ..                                                 ...
# 852  Indonesian International Student Mobility Awar...
# 853  Mendikbudristek: Mahasiswa Didorong Ikut Progr...
# 854  Maxy Academy Resmi Jadi Official Partner Kampu...
# 855  Beberapa di antaranya adalah program Kampus Me...
# 856  [cm] guys program kampus merdeka tuh semuanya ...
#
#                                          remove_number  \
# 0    ya kan gua bilang tergantung kampus pas awal" ...
# 1    Kak saya juga mengikuti program Bangkit dan sa...
# 2    . Kalau masih kupu" juga deket ama dosen haha ...
# 3    Diantara sekian banyak program kampus merdeka ...
# 4    tp ada saat dimana gua bersyukur banget dan be...
# ..                                                 ...
# 852  Indonesian International Student Mobility Awar...
# 853  Mendikbudristek: Mahasiswa Didorong Ikut Progr...
# 854  Maxy Academy Resmi Jadi Official Partner Kampu...
# 855  Beberapa di antaranya adalah program Kampus Me...
# 856  [cm] guys program kampus merdeka tuh semuanya ...
#
#                                               remove_p  \
# 0    ya kan gua bilang tergantung kampus pas awal K...
# 1    Kak saya juga mengikuti program Bangkit dan sa...
# 2     Kalau masih kupu juga deket ama dosen haha ka...
# 3    Diantara sekian banyak program kampus merdeka ...
# 4    tp ada saat dimana gua bersyukur banget dan be...
# ..                                                 ...
# 852  Indonesian International Student Mobility Awar...
# 853  Mendikbudristek Mahasiswa Didorong Ikut Progra...
# 854  Maxy Academy Resmi Jadi Official Partner Kampu...
# 855  Beberapa di antaranya adalah program Kampus Me...
# 856  cm guys program kampus merdeka tuh semuanya di...
#
#                                                 tokens  \
# 0    [ya, kan, gua, bilang, tergantung, kampus, pas...
# 1    [Kak, saya, juga, mengikuti, program, Bangkit,...
# 2    [Kalau, masih, kupu, juga, deket, ama, dosen, ...
# 3    [Diantara, sekian, banyak, program, kampus, me...
# 4    [tp, ada, saat, dimana, gua, bersyukur, banget...
# ..                                                 ...
# 852  [Indonesian, International, Student, Mobility,...
# 853  [Mendikbudristek, Mahasiswa, Didorong, Ikut, P...
# 854  [Maxy, Academy, Resmi, Jadi, Official, Partner...
# 855  [Beberapa, di, antaranya, adalah, program, Kam...
# 856  [cm, guys, program, kampus, merdeka, tuh, semu...
#
#                                               stopword  \
# 0    ya gua bilang tergantung kampus pas km aman ji...
# 1    kak mengikuti program bangkit salah melampirka...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp dimana gua bersyukur banget berasa dibutuhi...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa didorong program mer...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh dibayar gasih ...
#
#                                   remove_whitespace_LT  \
# 0    ya gua bilang tergantung kampus pas km aman ji...
# 1    kak mengikuti program bangkit salah melampirka...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp dimana gua bersyukur banget berasa dibutuhi...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa didorong program mer...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh dibayar gasih ...
#
#                             remove_whitespace_multiple  \
# 0    ya gua bilang tergantung kampus pas km aman ji...
# 1    kak mengikuti program bangkit salah melampirka...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp dimana gua bersyukur banget berasa dibutuhi...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa didorong program mer...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh dibayar gasih ...
#
#                                       preprocess_tweet
# 0    ya gua bilang gantung kampus pas km aman jir k...
# 1    kak ikut program bangkit salah lampir file spt...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp mana gua syukur banget asa dibutuhin pas ka...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa dorong program merde...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh bayar gasih st...
#
# [857 rows x 11 columns]

# %% [markdown]
# # 6. Menambahkan kolom baru dari hasil preprocessing
# Ini akan membuat kolom baru yang akan digunakan untuk proses selanjutnya dan menyimpan ke file csv dengan kolom yang sudah terpilih

# %%
cols_to_keep = ['preprocess_tweet', 'Label']
df_tweets = pd.read_csv('preprocessed.csv', usecols=cols_to_keep)
# menyimpan dataframe ke file csv dengan kolom yang telah dipilih sebelumnya
# df_tweets.to_csv('tweets_preprocessed.csv', index=False)

df_tweets['tweet_norm'] = df_tweets['preprocess_tweet']
df_tweets.to_csv('tweets_preprocessed.csv')

# %% [markdown]
# # 7. Load preprocessed data tweet

# %%
df_tweets = pd.read_csv('tweets_preprocessed.csv')
df_tweets.drop(df_tweets.filter(regex="Unname"),axis=1, inplace=True)

# %%
df_tweets
# Out:
#          Label                                   preprocess_tweet  \
# 0    Mendukung  ya gua bilang gantung kampus pas km aman jir k...
# 1    Mendukung  kak ikut program bangkit salah lampir file spt...
# 2    Mendukung  kupu deket ama dosen haha karna fun fact tetep...
# 3    Mendukung  sekian program kampus merdeka sih pmm tuh text...
# 4    Mendukung  tp mana gua syukur banget asa dibutuhin pas ka...
# ..         ...                                                ...
# 852  Mendukung  indonesian international student mobility awar...
# 853  Mendukung  mendikbudristek mahasiswa dorong program merde...
# 854  Mendukung  maxy academy resmi official partner kampus mer...
# 855  Mendukung  program kampus merdeka literasi digital beasis...
# 856  Mendukung  guys program kampus merdeka tuh bayar gasih st...
#
#                                             tweet_norm
# 0    ya gua bilang gantung kampus pas km aman jir k...
# 1    kak ikut program bangkit salah lampir file spt...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp mana gua syukur banget asa dibutuhin pas ka...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa dorong program merde...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh bayar gasih st...
#
# [857 rows x 3 columns]

# %% [markdown]
# # 8. Create freqDist_wrapper to counting frequency from each word

# %%
def freqDist_wrapper(text):
    return FreqDist(text)

df_tweets['tweet_tokens'] = df_tweets['tweet_norm'].apply(word_tokenize_wrapper)

df_tweets['tweet_tokens_fdist'] = df_tweets['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(df_tweets['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(kampus, 2), (yg, 2), (ya, 1), (gua, 1), (bil...
# 1    [(kak, 2), (sptjm, 2), (ikut, 1), (program, 1)...
# 2    [(dosen, 2), (karna, 2), (funded, 2), (kupu, 1...
# 3    [(sekian, 1), (program, 1), (kampus, 1), (merd...
# 4    [(gua, 5), (banget, 2), (kali, 2), (tp, 1), (m...
# Name: tweet_tokens_fdist, dtype: object

# %%
df_tweets.head(10)
# Out:
#        Label                                   preprocess_tweet  \
# 0  Mendukung  ya gua bilang gantung kampus pas km aman jir k...
# 1  Mendukung  kak ikut program bangkit salah lampir file spt...
# 2  Mendukung  kupu deket ama dosen haha karna fun fact tetep...
# 3  Mendukung  sekian program kampus merdeka sih pmm tuh text...
# 4  Mendukung  tp mana gua syukur banget asa dibutuhin pas ka...
# 5  Mendukung  id gin ya kak program kampus merdeka emang sed...
# 6  Mendukung  program sampe kampus merdeka tukar mahasiswa n...
# 7  Mendukung  program kampus merdeka lumayan uang jajan konv...
# 8  Mendukung  ceo tiktok konon magang kantor facebook ga sal...
# 9  Mendukung  kampus program magang salah unggul program mag...
#
#                                           tweet_norm  \
# 0  ya gua bilang gantung kampus pas km aman jir k...
# 1  kak ikut program bangkit salah lampir file spt...
# 2  kupu deket ama dosen haha karna fun fact tetep...
# 3  sekian program kampus merdeka sih pmm tuh text...
# 4  tp mana gua syukur banget asa dibutuhin pas ka...
# 5  id gin ya kak program kampus merdeka emang sed...
# 6  program sampe kampus merdeka tukar mahasiswa n...
# 7  program kampus merdeka lumayan uang jajan konv...
# 8  ceo tiktok konon magang kantor facebook ga sal...
# 9  kampus program magang salah unggul program mag...
#
#                                         tweet_tokens  \
# 0  [ya, gua, bilang, gantung, kampus, pas, km, am...
# 1  [kak, ikut, program, bangkit, salah, lampir, f...
# 2  [kupu, deket, ama, dosen, haha, karna, fun, fa...
# 3  [sekian, program, kampus, merdeka, sih, pmm, t...
# 4  [tp, mana, gua, syukur, banget, asa, dibutuhin...
# 5  [id, gin, ya, kak, program, kampus, merdeka, e...
# 6  [program, sampe, kampus, merdeka, tukar, mahas...
# 7  [program, kampus, merdeka, lumayan, uang, jaja...
# 8  [ceo, tiktok, konon, magang, kantor, facebook,...
# 9  [kampus, program, magang, salah, unggul, progr...
#
#                                   tweet_tokens_fdist
# 0  {'ya': 1, 'gua': 1, 'bilang': 1, 'gantung': 1,...
# 1  {'kak': 2, 'ikut': 1, 'program': 1, 'bangkit':...
# 2  {'kupu': 1, 'deket': 1, 'ama': 1, 'dosen': 2, ...
# 3  {'sekian': 1, 'program': 1, 'kampus': 1, 'merd...
# 4  {'tp': 1, 'mana': 1, 'gua': 5, 'syukur': 1, 'b...
# 5  {'id': 1, 'gin': 1, 'ya': 1, 'kak': 1, 'progra...
# 6  {'program': 2, 'sampe': 1, 'kampus': 3, 'merde...
# 7  {'program': 1, 'kampus': 1, 'merdeka': 1, 'lum...
# 8  {'ceo': 1, 'tiktok': 1, 'konon': 1, 'magang': ...
# 9  {'kampus': 3, 'program': 3, 'magang': 3, 'sala...

# %% [markdown]
# # 9. Create Clean_length function & convert_to_string
# Bertujuan untuk menghapus kata yang kurang dari 3 karakter

# %%
def Clean_length(token):
    return [i for i in token if len(i) > 3]
def convert_to_string(listReview):
    return ' '.join(listReview)

df_tweets['tweet_norm2'] = df_tweets['tweet_norm'].apply(word_tokenize_wrapper)
df_tweets['tweet_norm2'] = df_tweets['tweet_norm2'].apply(Clean_length)
df_tweets['tweet_norm2'] = df_tweets['tweet_norm2'].apply(convert_to_string)
# df_tweets['tweet_norm2'] = df_tweets['tweet_norm2'].apply(stopwords)

# %%
df_tweets
# Out:
#          Label                                   preprocess_tweet  \
# 0    Mendukung  ya gua bilang gantung kampus pas km aman jir k...
# 1    Mendukung  kak ikut program bangkit salah lampir file spt...
# 2    Mendukung  kupu deket ama dosen haha karna fun fact tetep...
# 3    Mendukung  sekian program kampus merdeka sih pmm tuh text...
# 4    Mendukung  tp mana gua syukur banget asa dibutuhin pas ka...
# ..         ...                                                ...
# 852  Mendukung  indonesian international student mobility awar...
# 853  Mendukung  mendikbudristek mahasiswa dorong program merde...
# 854  Mendukung  maxy academy resmi official partner kampus mer...
# 855  Mendukung  program kampus merdeka literasi digital beasis...
# 856  Mendukung  guys program kampus merdeka tuh bayar gasih st...
#
#                                             tweet_norm  \
# 0    ya gua bilang gantung kampus pas km aman jir k...
# 1    kak ikut program bangkit salah lampir file spt...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp mana gua syukur banget asa dibutuhin pas ka...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa dorong program merde...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh bayar gasih st...
#
#                                           tweet_tokens  \
# 0    [ya, gua, bilang, gantung, kampus, pas, km, am...
# 1    [kak, ikut, program, bangkit, salah, lampir, f...
# 2    [kupu, deket, ama, dosen, haha, karna, fun, fa...
# 3    [sekian, program, kampus, merdeka, sih, pmm, t...
# 4    [tp, mana, gua, syukur, banget, asa, dibutuhin...
# ..                                                 ...
# 852  [indonesian, international, student, mobility,...
# 853  [mendikbudristek, mahasiswa, dorong, program, ...
# 854  [maxy, academy, resmi, official, partner, kamp...
# 855  [program, kampus, merdeka, literasi, digital, ...
# 856  [guys, program, kampus, merdeka, tuh, bayar, g...
#
#                                     tweet_tokens_fdist  \
# 0    {'ya': 1, 'gua': 1, 'bilang': 1, 'gantung': 1,...
# 1    {'kak': 2, 'ikut': 1, 'program': 1, 'bangkit':...
# 2    {'kupu': 1, 'deket': 1, 'ama': 1, 'dosen': 2, ...
# 3    {'sekian': 1, 'program': 1, 'kampus': 1, 'merd...
# 4    {'tp': 1, 'mana': 1, 'gua': 5, 'syukur': 1, 'b...
# ..                                                 ...
# 852  {'indonesian': 1, 'international': 1, 'student...
# 853  {'mendikbudristek': 1, 'mahasiswa': 1, 'dorong...
# 854  {'maxy': 1, 'academy': 1, 'resmi': 1, 'officia...
# 855  {'program': 1, 'kampus': 1, 'merdeka': 1, 'lit...
# 856  {'guys': 1, 'program': 1, 'kampus': 1, 'merdek...
#
#                                            tweet_norm2
# 0    bilang gantung kampus aman karna program kampu...
# 1    ikut program bangkit salah lampir file sptjm k...
# 2    kupu deket dosen haha karna fact tetep subject...
# 3            sekian program kampus merdeka text hilang
# 4    mana syukur banget dibutuhin kampus merdeka ke...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa dorong program merde...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka bayar gasih studi ...
#
# [857 rows x 6 columns]

# %% [markdown]
# # 10. Result of preprocessed data tweet
# * **label** -> Mendukung / Tidak Mendukung
# * **tweet** -> Ikut studi independen seru, belajar dapat ilmu sekaligus uang juga...
# * **tweet_norm** -> kata yang sudah di normalisasi/preprocess
# * **tweet_tokens** -> memisahkan setiap kata kemudian diubah menjadi list sebagai processing text nanti
# * **tweet_tokens_fdist** -> mencari frekuensi dari setiap kata
# * **tweet_norm2** -> Kata-kata yang sudah tidak memiliki kata kurang dari 4 karakter
# * **label_id** -> Label yang sudah diubah menjadi numerical

# %% [markdown]
# # 11. Count unique words in data tweet

# %%
unique_string = set()
for x in df_tweets['tweet_norm2']:
    for y in x.split():
        unique_string.add(y)
        
len(unique_string)
# Out:
# 2574

# %%
unique_string
# Out:
# {'sumpahh',
#  'kacau',
#  'bakat',
#  'gera',
#  'otak',
#  'stay',
#  'komisi',
#  'misuh',
#  'kacang',
#  'manfaat',
#  'gagal',
#  'kampsusnya',
#  'proof',
#  'nurture',
#  'awardee',
#  'beres',
#  'bole',
#  'bolak',
#  'engga',
#  'banyuwangi',
#  'negara',
#  'jugaa',
#  'anjink',
#  'ordal',
#  'mobilitas',
#  'free',
#  'drpd',
#  'silang',
#  'open',
#  'kejar',
#  'komen',
#  'fatek',
#  'disalahin',
#  'ngerjain',
#  'bgtt',
#  'komenin',
#  'nadim',
#  'janji',
#  'bencooleen',
#  'kondisi',
#  'jepang',
#  'passion',
#  'temenan',
#  'woii',
#  'worth',
#  'minkar',
#  'akreditasi',
#  'modal',
#  'tingkat',
#  'like',
#  'bantah',
#  'pacu',
#  'ignya',
#  'kura',
#  'dilema',
#  'tetangga',
#  'ilusi',
#  'iism',
#  'laprak',
#  'jentera',
#  'sesal',
#  'yaampun',
#  'lewat',
#  'telegram',
#  'basic',
#  'virtual',
#  'yeah',
#  'chanel',
#  'kalo',
#  'panjange',
#  'seksi',
#  'relevansi',
#  'gtpilih',
#  'stimik',
#  'alami',
#  'mengjar',
#  'partner',
#  'masyarakat',
#  'indroktinisasi',
#  'australia',
#  'diswitch',
#  'organisasi',
#  'sesuai',
#  'anjrit',
#  'kelak',
#  'dicoding',
#  'struggle',
#  'uncen',
#  'gitu',
#  'nalar',
#  'sepakat',
#  'kuat',
#  'jogja',
#  'peduli',
#  'akang',
#  'issues',
#  'form',
#  'bgmn',
#  'beberpa',
#  'systems',
#  'yhhh',
#  'gantiin',
#  'abis',
#  'tidur',
#  'sastra',
#  'lainnnya',
#  'feelku',
#  'voucher',
#  'skip',
#  'fauzi',
#  'susah',
#  'laksana',
#  'lhokseumawe',
#  'doktor',
#  'batchnya',
#  'worries',
#  'seremoni',
#  'salin',
#  'ternyataa',
#  'fomo',
#  'kabur',
#  'trust',
#  'konserrr',
#  'waldos',
#  'self',
#  'rombak',
#  'bandung',
#  'penuh',
#  'mikir',
#  'instagram',
#  'sdikantisang',
#  'padu',
#  'cari',
#  'matakuliah',
#  'baca',
#  'hailahh',
#  'duta',
#  'ngurusin',
#  'engineering',
#  'kinda',
#  'plus',
#  'jenapa',
#  'gakk',
#  'bela',
#  'force',
#  'bina',
#  'sintang',
#  'presentasi',
#  'taun',
#  'modif',
#  'tembok',
#  'radio',
#  'funded',
#  'miris',
#  'asia',
#  'about',
#  'session',
#  'ngecek',
#  'batalin',
#  'gesit',
#  'cacat',
#  'upgrade',
#  'smua',
#  'ngedrop',
#  'dijejelin',
#  'singkat',
#  'tepat',
#  'smester',
#  'kuliah',
#  'arah',
#  'jelek',
#  'status',
#  'responden',
#  'belanja',
#  'revisi',
#  'nabrak',
#  'kebhinekaan',
#  'goto',
#  'kirain',
#  'offense',
#  'mesir',
#  'serasa',
#  'ditanyain',
#  'ternate',
#  'anjit',
#  'karantina',
#  'pendidikanislam',
#  'rendah',
#  'rada',
#  'agrotek',
#  'dimanfaatin',
#  'anjinggg',
#  'astaga',
#  'ambil',
#  'mahasiswa',
#  'fokus',
#  'praktik',
#  'kelompok',
#  'skeptical',
#  'text',
#  'diri',
#  'bakar',
#  'abar',
#  'pmmnya',
#  'volunteer',
#  'gtliat',
#  'rumpun',
#  'dilakuin',
#  'tema',
#  'ubah',
#  'mbingungin',
#  'charge',
#  'kamjarr',
#  'wkwk',
#  'upload',
#  'gmna',
#  'fenomena',
#  'rujak',
#  'kompetisi',
#  'perihal',
#  'cowonya',
#  'proyek',
#  'bpsi',
#  'wicis',
#  'sakdurunge',
#  'sehat',
#  'dsbnya',
#  'gelora',
#  'terima',
#  'yaudah',
#  'sulit',
#  'awam',
#  'buzzer',
#  'ngambil',
#  'laptop',
#  'generalis',
#  'multitasking',
#  'diwajibno',
#  'umrah',
#  'malut',
#  'maluin',
#  'nikmat',
#  'realisasi',
#  'forecaster',
#  'bgstt',
#  'tulis',
#  'sudirman',
#  'berkahir',
#  'padet',
#  'ngucapin',
#  'shanti',
#  'betuuulll',
#  'aplgi',
#  'karna',
#  'bhkan',
#  'unhas',
#  'sektor',
#  'maksusnya',
#  'intern',
#  'sempro',
#  'niat',
#  'konsekuensi',
#  'kepala',
#  'sadar',
#  'informasi',
#  'smpet',
#  'akhir',
#  'capai',
#  'verifikasi',
#  'menindaklanjuti',
#  'skill',
#  'diadain',
#  'fase',
#  'fisip',
#  'gamasalah',
#  'bootcamp',
#  'please',
#  'beuhhh',
#  'nota',
#  'diskusi',
#  'makasii',
#  'kuma',
#  'sorry',
#  'slalu',
#  'travelovers',
#  'bias',
#  'pacar',
#  'paragon',
#  'belas',
#  'selesai',
#  'izin',
#  'pengalamannua',
#  'respon',
#  'pribadi',
#  'lucu',
#  'ruangguru',
#  'jawa',
#  'aahhhh',
#  'taruna',
#  'canang',
#  'promo',
#  'lpdp',
#  'nelpon',
#  'byarnya',
#  'lengkap',
#  'moodswing',
#  'tanam',
#  'familiar',
#  'selamat',
#  'daftar',
#  'efek',
#  'stpn',
#  'libur',
#  'suguh',
#  'pertamakali',
#  'blue',
#  'unwahas',
#  'reguler',
#  'mental',
#  'nangkepnya',
#  'dibutuhin',
#  'spatugas',
#  'kooo',
#  'kiyai',
#  'palsu',
#  'bangkit',
#  'grgr',
#  'brwa',
#  'nakes',
#  'cowo',
#  'anggur',
#  'kamila',
#  'wadah',
#  'gitulah',
#  'tusuk',
#  'ngedesain',
#  'unspress',
#  'tips',
#  'tuhan',
#  'kompetensi',
#  'learn',
#  'dekan',
#  'kesel',
#  'dibandingin',
#  'mipa',
#  'ngeri',
#  'mampus',
#  'nafkah',
#  'pulang',
#  'nyesel',
#  'thinking',
#  'linimasa',
#  'tenaga',
#  'berangkat',
#  'tauuuu',
#  'musim',
#  'surabaya',
#  'nashwa',
#  'usahain',
#  'julidin',
#  'nutrifood',
#  'litrerasi',
#  'tandatangani',
#  'besok',
#  'lakik',
#  'semarang',
#  'jember',
#  'ngakalinnya',
#  'kmren',
#  'karier',
#  'lipat',
#  'abdi',
#  'surpotif',
#  'ngamuk',
#  'huhuhu',
#  'cuaca',
#  'kloter',
#  'ngebut',
#  'subay',
#  'lanjot',
#  'iyaaa',
#  'hima',
#  'ancur',
#  'teknis',
#  'pontianak',
#  'cadang',
#  'actually',
#  'uang',
#  'beneran',
#  'seminar',
#  'lulus',
#  'bain',
#  'heni',
#  'ngepush',
#  'nasarudin',
#  'hard',
#  'zoom',
#  'hukumonline',
#  'ntar',
#  'asset',
#  'ngobrol',
#  'cetus',
#  'jenis',
#  'instrumen',
#  'hohoho',
#  'bsok',
#  'trisakti',
#  'pratama',
#  'mudah',
#  'keinget',
#  'gunung',
#  'iisma',
#  'cabs',
#  'after',
#  'makas',
#  'halte',
#  'webinar',
#  'benefits',
#  'unit',
#  'paksa',
#  'nganggur',
#  'nizam',
#  'mengajarprodiku',
#  'swasta',
#  'gaada',
#  'undur',
#  'agenda',
#  'stiap',
#  'experience',
#  'official',
#  'pinned',
#  'hati',
#  'kamjar',
#  'timelinenya',
#  'jasa',
#  'ancam',
#  'teknik',
#  'long',
#  'redup',
#  'mixue',
#  'ganti',
#  'tbtb',
#  'tahu',
#  'uniska',
#  'kudu',
#  'tweet',
#  'akehh',
#  'dicuekin',
#  'bruh',
#  'hadeh',
#  'bareng',
#  'kenal',
#  'ikan',
#  'dyandra',
#  'rasuk',
#  'baharu',
#  'hihihi',
#  'damping',
#  'fatal',
#  'administrasi',
#  'nunggu',
#  'bicara',
#  'salha',
#  'kedok',
#  'panik',
#  'teman',
#  'gform',
#  'document',
#  'course',
#  'gapunya',
#  'bayi',
#  'dripada',
#  'perhati',
#  'mahasiswi',
#  'roboh',
#  'gegara',
#  'kreatif',
#  'katarima',
#  'riview',
#  'agribisnis',
#  'hardsoftskill',
#  'provinsi',
#  'dalam',
#  'nahasiswa',
#  'atleast',
#  'arsi',
#  'miss',
#  'with',
#  'nyobain',
#  'cokkk',
#  'electives',
#  'sial',
#  'anjing',
#  'infrastruktur',
#  'asisten',
#  'angus',
#  'pikir',
#  'juang',
#  'kunjung',
#  'badan',
#  'jdinya',
#  'kayak',
#  'jugak',
#  'kemenkeu',
#  'dato',
#  'kritis',
#  'food',
#  'alhasil',
#  'final',
#  'pandemi',
#  'pragmatisme',
#  'nyari',
#  'pengaruh',
#  'saiman',
#  'gasie',
#  'mumettt',
#  'abrek',
#  'kadin',
#  'ngikut',
#  'guna',
#  'malikussaleh',
#  'orang',
#  'pandu',
#  'coding',
#  'gapapaa',
#  'seribet',
#  'first',
#  'ajar',
#  'center',
#  'setiausaha',
#  'mohd',
#  'maloe',
#  'mutualkuu',
#  'muncul',
#  'survive',
#  'enak',
#  'fardhu',
#  'instagramnya',
#  'konsentrasi',
#  'staff',
#  'tiga',
#  'aahh',
#  'berlindug',
#  'bmkg',
#  'publik',
#  'peirhal',
#  'hahaha',
#  'mysonis',
#  'going',
#  'gituu',
#  'pusat',
#  'kapitalisme',
#  'asistensi',
#  'nahh',
#  'dianggurin',
#  'namo',
#  'asumsi',
#  'untag',
#  'pertukaranmahasiswamerdeka',
#  'maksimalin',
#  'pusing',
#  'beban',
#  'besmart',
#  'gerak',
#  'sedot',
#  'paid',
#  'bird',
#  'hate',
#  'duduk',
#  'collab',
#  'sabar',
#  'inget',
#  'inbound',
#  'cewe',
#  'eligible',
#  'lokakarya',
#  'andang',
#  'kakak',
#  'pliss',
#  'saran',
#  'fight',
#  'tekpend',
#  'independensemacam',
#  'interview',
#  'adaa',
#  'urus',
#  'timbang',
#  'lagih',
#  'ngampusnya',
#  'nominal',
#  'aduh',
#  'ngelead',
#  'ngomong',
#  'raya',
#  'klian',
#  'pantengin',
#  'scan',
#  'lingkup',
#  'nggu',
#  'kabinet',
#  'indeks',
#  'tiktok',
#  'gakjadi',
#  'kontol',
#  'tiket',
#  'explore',
#  'kasubbag',
#  'begitu',
#  'hallo',
#  'campus',
#  'bpii',
#  'maxy',
#  'itunsalah',
#  'time',
#  'keteter',
#  'siswi',
#  'serta',
#  'ngebem',
#  'komunikasi',
#  'kreativitas',
#  'johni',
#  'yakkkk',
#  'ketrima',
#  'kuasa',
#  'anjer',
#  'ahli',
#  'besar',
#  'prospek',
#  'senior',
#  'pusatinformasi',
#  'sertifikat',
#  'basa',
#  'teknokrat',
#  'tuju',
#  'overthinking',
#  'cipta',
#  'fakkk',
#  'bego',
#  'acara',
#  'prestasi',
#  'kostbiaya',
#  'auto',
#  'tampar',
#  'ubhara',
#  'generalisasi',
#  'kemaren',
#  'campusbrainers',
#  'brapa',
#  'biar',
#  'gede',
#  'hilir',
#  'tukar',
#  'vokasional',
#  'mahasiwa',
#  'mgkn',
#  'questions',
#  'minat',
#  'flow',
#  'embel',
#  'trees',
#  'dukung',
#  'offline',
#  'kknnya',
#  'jajan',
#  'barusan',
#  'ngene',
#  'ngampus',
#  'bimbing',
#  'materi',
#  'lagi',
#  'buru',
#  'makul',
#  'semuaaaaaahhhhh',
#  'baik',
#  'nyaman',
#  'studi',
#  'sing',
#  'sasar',
#  'rifqi',
#  'aneka',
#  'putar',
#  'kerjain',
#  'pesimis',
#  'bangga',
#  'admin',
#  'mhsw',
#  'hurts',
#  'kerap',
#  'transparansi',
#  'atur',
#  'cerdas',
#  'koriyah',
#  'usaha',
#  'meteorologi',
#  'makkkk',
#  'mksdnya',
#  'gasih',
#  'rapel',
#  'nyentuh',
#  'woiiii',
#  'bicaramenyoal',
#  'dora',
#  'muak',
#  'sihh',
#  'dept',
#  'dorong',
#  'profesi',
#  'thailand',
#  'syuliittt',
#  'undang',
#  'batas',
#  'instansi',
#  'terkadang',
#  'kalah',
#  'kategori',
#  'wellnesss',
#  'teacher',
#  'tergajelas',
#  'hortikultura',
#  'sendri',
#  'bgtttt',
#  'kecewa',
#  'sense',
#  'nyokap',
#  'mufida',
#  'elektro',
#  'baru',
#  'rangka',
#  'offerinh',
#  'praktek',
#  'even',
#  'leave',
#  'update',
#  'atas',
#  'tineline',
#  'kepingin',
#  'least',
#  'tipu',
#  'minimal',
#  'harap',
#  'univ',
#  'panitia',
#  'kemendikbudristek',
#  'kait',
#  'panampuiii',
#  'jabat',
#  'wktu',
#  'ribet',
#  'yaaa',
#  'student',
#  'maksimal',
#  'drastis',
#  'depan',
#  'empat',
#  'indonesian',
#  'gengs',
#  'pegang',
#  'skilvul',
#  'rabu',
#  'topic',
#  'kuota',
#  'tanjungpura',
#  'sipil',
#  'fadhilah',
#  'travelxism',
#  'mengakomodir',
#  'tumpang',
#  'sndiri',
#  'tahniah',
#  'kemdikbud',
#  'hari',
#  'bebas',
#  'coaching',
#  'tematik',
#  'stiper',
#  'soalny',
#  'ahahahah',
#  'galang',
#  'puji',
#  'corporation',
#  'turun',
#  'ngerasa',
#  'sekolah',
#  'lompok',
#  'bohong',
#  'banyak',
#  'suka',
#  'planning',
#  'relate',
#  'true',
#  'oleh',
#  'rektor',
#  'seengganya',
#  'upaya',
#  'ngundurin',
#  'later',
#  'semester',
#  'mene',
#  'kalimantan',
#  'friendly',
#  'kesamber',
#  'reree',
#  'gaji',
#  'halang',
#  'muka',
#  'dongkrak',
#  'temu',
#  'krna',
#  'alesan',
#  'peluang',
#  'dipake',
#  'buat',
#  'thank',
#  'screening',
#  'udah',
#  'interest',
#  'unud',
#  'pijar',
#  'sore',
#  'pricelist',
#  'cermin',
#  'sendiri',
#  'individu',
#  'sebal',
#  'pamer',
#  'aowkaow',
#  'politics',
#  'siang',
#  'gais',
#  'almetnya',
#  'manteri',
#  'sebenenya',
#  'curhat',
#  'solidaritas',
#  'posisi',
#  'tempuh',
#  'paus',
#  'sulawesi',
#  'bale',
#  'kosong',
#  'club',
#  'kebut',
#  'kemenkumham',
#  'kendalpayak',
#  'linkedin',
#  'softskills',
#  'perkar',
#  'bencooleeners',
#  'pake',
#  'tesinterview',
#  'hama',
#  'seni',
#  'demen',
#  'anggar',
#  'kadang',
#  'ditandatangani',
#  'bgst',
#  'arti',
#  'korprodi',
#  'zawawi',
#  'sumpahhh',
#  'serah',
#  'kaget',
#  'deadline',
#  'ganggu',
#  'ngajar',
#  'servis',
#  'anjg',
#  'publish',
#  'tentuu',
#  'duluan',
#  'dirjen',
#  'rebut',
#  'lampung',
#  'gading',
#  'also',
#  'taiikkk',
#  'power',
#  'eksplorasi',
#  'pmmb',
#  'tanyarl',
#  'iptp',
#  'fungsi',
#  'poin',
#  'ngapa',
#  'tugas',
#  'agustus',
#  'keburu',
#  'lagiii',
#  'bayangin',
#  'internal',
#  'konservasi',
#  'bmkgjogja',
#  'jurusanuniv',
#  'short',
#  'tjahjanto',
#  'gimanaaaaa',
#  'temen',
#  'adnan',
#  'indonesia',
#  'integrasi',
#  'alumni',
#  'telkom',
#  'balik',
#  'share',
#  'kebiri',
#  'direject',
#  'rakyat',
#  'konteks',
#  'pengin',
#  'rampung',
#  'mantau',
#  'pimpin',
#  'tekonis',
#  'tumbuh',
#  'mulu',
#  'ucap',
#  'kupake',
#  'himpun',
#  'ketemu',
#  'malu',
#  'mesti',
#  'organ',
#  'panggil',
#  'bencoolen',
#  'kompas',
#  'ntah',
#  'typo',
#  'bolos',
#  'susahh',
#  'festival',
#  'gajes',
#  'serame',
#  'kenang',
#  'henti',
#  'letak',
#  'relatif',
#  'nambah',
#  'niiai',
#  'genah',
#  'anggap',
#  'buka',
#  'resmi',
#  'klsnya',
#  'selenggara',
#  'akrab',
#  'inggris',
#  'senggang',
#  'info',
#  'hibah',
#  'pindah',
#  'angkat',
#  'program',
#  'teripuhhhh',
#  'platform',
#  'word',
#  'study',
#  'colong',
#  'gada',
#  'safety',
#  'kerjasama',
#  'ikutin',
#  'tujuh',
#  'rekomended',
#  'jarang',
#  'fast',
#  'bisa',
#  'telutizen',
#  'kucing',
#  'gweh',
#  'domisili',
#  'mandiri',
#  'lohhh',
#  'bebanin',
#  'dosen',
#  'ditawarin',
#  'permisi',
#  'inspirasi',
#  'tinggi',
#  'lirik',
#  'keriweuhan',
#  'part',
#  'daftarin',
#  'teori',
#  'thats',
#  'ngejar',
#  'yatuhan',
#  'agen',
#  'diajarin',
#  'jalur',
#  'bidang',
#  'lapang',
#  'revision',
#  'ngulati',
#  'wujud',
#  'gajadi',
#  'jancokkk',
#  'nugas',
#  'segitu',
#  'nyata',
#  ...}

# %% [markdown]
# # 12. Change label into number

# %%
df_tweets['label_id'] = df_tweets['Label'].map({"Mendukung": 1, "Tidak Mendukung": 0 })
from io import StringIO
kategori_id_data = df_tweets[['Label', 'label_id']].drop_duplicates().sort_values('label_id', ascending=False)
kategori_to_id = dict(kategori_id_data.values)
id_to_kategori = dict(kategori_id_data[['label_id', 'Label']].values)
df_tweets
# Out:
#          Label                                   preprocess_tweet  \
# 0    Mendukung  ya gua bilang gantung kampus pas km aman jir k...
# 1    Mendukung  kak ikut program bangkit salah lampir file spt...
# 2    Mendukung  kupu deket ama dosen haha karna fun fact tetep...
# 3    Mendukung  sekian program kampus merdeka sih pmm tuh text...
# 4    Mendukung  tp mana gua syukur banget asa dibutuhin pas ka...
# ..         ...                                                ...
# 852  Mendukung  indonesian international student mobility awar...
# 853  Mendukung  mendikbudristek mahasiswa dorong program merde...
# 854  Mendukung  maxy academy resmi official partner kampus mer...
# 855  Mendukung  program kampus merdeka literasi digital beasis...
# 856  Mendukung  guys program kampus merdeka tuh bayar gasih st...
#
#                                             tweet_norm  \
# 0    ya gua bilang gantung kampus pas km aman jir k...
# 1    kak ikut program bangkit salah lampir file spt...
# 2    kupu deket ama dosen haha karna fun fact tetep...
# 3    sekian program kampus merdeka sih pmm tuh text...
# 4    tp mana gua syukur banget asa dibutuhin pas ka...
# ..                                                 ...
# 852  indonesian international student mobility awar...
# 853  mendikbudristek mahasiswa dorong program merde...
# 854  maxy academy resmi official partner kampus mer...
# 855  program kampus merdeka literasi digital beasis...
# 856  guys program kampus merdeka tuh bayar gasih st...
#
#                                           tweet_tokens  \
# 0    [ya, gua, bilang, gantung, kampus, pas, km, am...
# 1    [kak, ikut, program, bangkit, salah, lampir, f...
# 2    [kupu, deket, ama, dosen, haha, karna, fun, fa...
# 3    [sekian, program, kampus, merdeka, sih, pmm, t...
# 4    [tp, mana, gua, syukur, banget, asa, dibutuhin...
# ..                                                 ...
# 852  [indonesian, international, student, mobility,...
# 853  [mendikbudristek, mahasiswa, dorong, program, ...
# 854  [maxy, academy, resmi, official, partner, kamp...
# 855  [program, kampus, merdeka, literasi, digital, ...
# 856  [guys, program, kampus, merdeka, tuh, bayar, g...
#
#                                     tweet_tokens_fdist  \
# 0    {'ya': 1, 'gua': 1, 'bilang': 1, 'gantung': 1,...
# 1    {'kak': 2, 'ikut': 1, 'program': 1, 'bangkit':...
# 2    {'kupu': 1, 'deket': 1, 'ama': 1, 'dosen': 2, ...
# 3    {'sekian': 1, 'program': 1, 'kampus': 1, 'merd...
# 4    {'tp': 1, 'mana': 1, 'gua': 5, 'syukur': 1, 'b...
# ..                                                 ...
# 852  {'indonesian': 1, 'international': 1, 'student...
# 853  {'mendikbudristek': 1, 'mahasiswa': 1, 'dorong...
# 854  {'maxy': 1, 'academy': 1, 'resmi': 1, 'officia...
# 855  {'program': 1, 'kampus': 1, 'merdeka': 1, 'lit...
# 856  {'guys': 1, 'program': 1, 'kampus': 1, 'merdek...
#
#                                            tweet_norm2  label_id
# 0    bilang gantung kampus aman karna program kampu...         1
# 1    ikut program bangkit salah lampir file sptjm k...         1
# 2    kupu deket dosen haha karna fact tetep subject...         1
# 3            sekian program kampus merdeka text hilang         1
# 4    mana syukur banget dibutuhin kampus merdeka ke...         1
# ..                                                 ...       ...
# 852  indonesian international student mobility awar...         1
# 853  mendikbudristek mahasiswa dorong program merde...         1
# 854  maxy academy resmi official partner kampus mer...         1
# 855  program kampus merdeka literasi digital beasis...         1
# 856  guys program kampus merdeka bayar gasih studi ...         1
#
# [857 rows x 7 columns]

# %%
preprocessed=[]
for i in df_tweets['tweet_norm2']:
  preprocessed.append({"tweet": i})
pd.set_option('display.max_colwidth', 1)
pd.DataFrame(preprocessed)
# Out:
#                                                                                                                                                                    tweet
# 0    bilang gantung kampus aman karna program kampus merdeka naikin akreditasi fakultas minat susah wkwk
# 1    ikut program bangkit salah lampir file sptjm kampus merdeka revisi sptjm gform document revision harap email
# 2    kupu deket dosen haha karna fact tetep subjective temen angkat exchange self funded karna kenal dosen untung sabar program permata sakti kampus merdeka full funded
# 3    sekian program kampus merdeka text hilang
# 4    mana syukur banget dibutuhin kampus merdeka kemarin temen sampe kali kali bilang makasih karna udah bantu program terharuu banget serius kayak orang ngerasa guna
# ..                                                                                                                                                                 ...
# 852  indonesian international student mobility awards salah program kampus merdeka
# 853  mendikbudristek mahasiswa dorong program merdeka ajar kampus merdeka
# 854  maxy academy resmi official partner kampus merdeka msib batch bank dunia prediksi indonesia alami kurang juta tenaga digital perintah upaya atas program
# 855  program kampus merdeka literasi digital beasiswa didik guru
# 856  guys program kampus merdeka bayar gasih studi independent ajar
#
# [857 rows x 1 columns]

# %%
df_tweets['tweet_norm2'].to_csv('norm2.csv')

# %%
df_tweets
# Out:
#          Label  \
# 0    Mendukung
# 1    Mendukung
# 2    Mendukung
# 3    Mendukung
# 4    Mendukung
# ..         ...
# 852  Mendukung
# 853  Mendukung
# 854  Mendukung
# 855  Mendukung
# 856  Mendukung
#
#                                                                                                                                                                                         preprocess_tweet  \
# 0    ya gua bilang gantung kampus pas km aman jir karna emg yg program kampus merdeka naikin akreditasi fakultas yg minat susah wkwk
# 1    kak ikut program bangkit salah lampir file sptjm kampus merdeka revisi sr sptjm gform document revision harap email kak
# 2    kupu deket ama dosen haha karna fun fact tetep subjective nya temen angkat exchange bal self funded tu karna kenal dosen untung sabar ga program permata sakti kampus merdeka yg full funded
# 3    sekian program kampus merdeka sih pmm tuh text hilang
# 4    tp mana gua syukur banget asa dibutuhin pas kampus merdeka kemarin temen gua sampe kali kali bilang makasih gua karna udah bantu program gua terharuu banget serius kayak orang yg ngerasa gua guna
# ..                                                                                                                                                                                                   ...
# 852  indonesian international student mobility awards salah program kampus merdeka ri
# 853  mendikbudristek mahasiswa dorong program merdeka ajar kampus merdeka
# 854  maxy academy resmi official partner kampus merdeka msib batch bank dunia prediksi indonesia alami kurang juta tenaga digital perintah upaya atas ada program
# 855  program kampus merdeka literasi digital beasiswa didik guru
# 856  guys program kampus merdeka tuh bayar gasih studi independent ajar aja
#
#                                                                                                                                                                                               tweet_norm  \
# 0    ya gua bilang gantung kampus pas km aman jir karna emg yg program kampus merdeka naikin akreditasi fakultas yg minat susah wkwk
# 1    kak ikut program bangkit salah lampir file sptjm kampus merdeka revisi sr sptjm gform document revision harap email kak
# 2    kupu deket ama dosen haha karna fun fact tetep subjective nya temen angkat exchange bal self funded tu karna kenal dosen untung sabar ga program permata sakti kampus merdeka yg full funded
# 3    sekian program kampus merdeka sih pmm tuh text hilang
# 4    tp mana gua syukur banget asa dibutuhin pas kampus merdeka kemarin temen gua sampe kali kali bilang makasih gua karna udah bantu program gua terharuu banget serius kayak orang yg ngerasa gua guna
# ..                                                                                                                                                                                                   ...
# 852  indonesian international student mobility awards salah program kampus merdeka ri
# 853  mendikbudristek mahasiswa dorong program merdeka ajar kampus merdeka
# 854  maxy academy resmi official partner kampus merdeka msib batch bank dunia prediksi indonesia alami kurang juta tenaga digital perintah upaya atas ada program
# 855  program kampus merdeka literasi digital beasiswa didik guru
# 856  guys program kampus merdeka tuh bayar gasih studi independent ajar aja
#
#                                                                                                                                                                                                                               tweet_tokens  \
# 0    [ya, gua, bilang, gantung, kampus, pas, km, aman, jir, karna, emg, yg, program, kampus, merdeka, naikin, akreditasi, fakultas, yg, minat, susah, wkwk]
# 1    [kak, ikut, program, bangkit, salah, lampir, file, sptjm, kampus, merdeka, revisi, sr, sptjm, gform, document, revision, harap, email, kak]
# 2    [kupu, deket, ama, dosen, haha, karna, fun, fact, tetep, subjective, nya, temen, angkat, exchange, bal, self, funded, tu, karna, kenal, dosen, untung, sabar, ga, program, permata, sakti, kampus, merdeka, yg, full, funded]
# 3    [sekian, program, kampus, merdeka, sih, pmm, tuh, text, hilang]
# 4    [tp, mana, gua, syukur, banget, asa, dibutuhin, pas, kampus, merdeka, kemarin, temen, gua, sampe, kali, kali, bilang, makasih, gua, karna, udah, bantu, program, gua, terharuu, banget, serius, kayak, orang, yg, ngerasa, gua, guna]
# ..                                                                                                                                                                                                                                     ...
# 852  [indonesian, international, student, mobility, awards, salah, program, kampus, merdeka, ri]
# 853  [mendikbudristek, mahasiswa, dorong, program, merdeka, ajar, kampus, merdeka]
# 854  [maxy, academy, resmi, official, partner, kampus, merdeka, msib, batch, bank, dunia, prediksi, indonesia, alami, kurang, juta, tenaga, digital, perintah, upaya, atas, ada, program]
# 855  [program, kampus, merdeka, literasi, digital, beasiswa, didik, guru]
# 856  [guys, program, kampus, merdeka, tuh, bayar, gasih, studi, independent, ajar, aja]
#
#                                                                                                                                                                                                                                                                                                                                            tweet_tokens_fdist  \
# 0    {'ya': 1, 'gua': 1, 'bilang': 1, 'gantung': 1, 'kampus': 2, 'pas': 1, 'km': 1, 'aman': 1, 'jir': 1, 'karna': 1, 'emg': 1, 'yg': 2, 'program': 1, 'merdeka': 1, 'naikin': 1, 'akreditasi': 1, 'fakultas': 1, 'minat': 1, 'susah': 1, 'wkwk': 1}
# 1    {'kak': 2, 'ikut': 1, 'program': 1, 'bangkit': 1, 'salah': 1, 'lampir': 1, 'file': 1, 'sptjm': 2, 'kampus': 1, 'merdeka': 1, 'revisi': 1, 'sr': 1, 'gform': 1, 'document': 1, 'revision': 1, 'harap': 1, 'email': 1}
# 2    {'kupu': 1, 'deket': 1, 'ama': 1, 'dosen': 2, 'haha': 1, 'karna': 2, 'fun': 1, 'fact': 1, 'tetep': 1, 'subjective': 1, 'nya': 1, 'temen': 1, 'angkat': 1, 'exchange': 1, 'bal': 1, 'self': 1, 'funded': 2, 'tu': 1, 'kenal': 1, 'untung': 1, 'sabar': 1, 'ga': 1, 'program': 1, 'permata': 1, 'sakti': 1, 'kampus': 1, 'merdeka': 1, 'yg': 1, 'full': 1}
# 3    {'sekian': 1, 'program': 1, 'kampus': 1, 'merdeka': 1, 'sih': 1, 'pmm': 1, 'tuh': 1, 'text': 1, 'hilang': 1}
# 4    {'tp': 1, 'mana': 1, 'gua': 5, 'syukur': 1, 'banget': 2, 'asa': 1, 'dibutuhin': 1, 'pas': 1, 'kampus': 1, 'merdeka': 1, 'kemarin': 1, 'temen': 1, 'sampe': 1, 'kali': 2, 'bilang': 1, 'makasih': 1, 'karna': 1, 'udah': 1, 'bantu': 1, 'program': 1, 'terharuu': 1, 'serius': 1, 'kayak': 1, 'orang': 1, 'yg': 1, 'ngerasa': 1, 'guna': 1}
# ..                                                                                                                                                                                                                                                                                                                                          ...
# 852  {'indonesian': 1, 'international': 1, 'student': 1, 'mobility': 1, 'awards': 1, 'salah': 1, 'program': 1, 'kampus': 1, 'merdeka': 1, 'ri': 1}
# 853  {'mendikbudristek': 1, 'mahasiswa': 1, 'dorong': 1, 'program': 1, 'merdeka': 2, 'ajar': 1, 'kampus': 1}
# 854  {'maxy': 1, 'academy': 1, 'resmi': 1, 'official': 1, 'partner': 1, 'kampus': 1, 'merdeka': 1, 'msib': 1, 'batch': 1, 'bank': 1, 'dunia': 1, 'prediksi': 1, 'indonesia': 1, 'alami': 1, 'kurang': 1, 'juta': 1, 'tenaga': 1, 'digital': 1, 'perintah': 1, 'upaya': 1, 'atas': 1, 'ada': 1, 'program': 1}
# 855  {'program': 1, 'kampus': 1, 'merdeka': 1, 'literasi': 1, 'digital': 1, 'beasiswa': 1, 'didik': 1, 'guru': 1}
# 856  {'guys': 1, 'program': 1, 'kampus': 1, 'merdeka': 1, 'tuh': 1, 'bayar': 1, 'gasih': 1, 'studi': 1, 'independent': 1, 'ajar': 1, 'aja': 1}
#
#                                                                                                                                                              tweet_norm2  \
# 0    bilang gantung kampus aman karna program kampus merdeka naikin akreditasi fakultas minat susah wkwk
# 1    ikut program bangkit salah lampir file sptjm kampus merdeka revisi sptjm gform document revision harap email
# 2    kupu deket dosen haha karna fact tetep subjective temen angkat exchange self funded karna kenal dosen untung sabar program permata sakti kampus merdeka full funded
# 3    sekian program kampus merdeka text hilang
# 4    mana syukur banget dibutuhin kampus merdeka kemarin temen sampe kali kali bilang makasih karna udah bantu program terharuu banget serius kayak orang ngerasa guna
# ..                                                                                                                                                                 ...
# 852  indonesian international student mobility awards salah program kampus merdeka
# 853  mendikbudristek mahasiswa dorong program merdeka ajar kampus merdeka
# 854  maxy academy resmi official partner kampus merdeka msib batch bank dunia prediksi indonesia alami kurang juta tenaga digital perintah upaya atas program
# 855  program kampus merdeka literasi digital beasiswa didik guru
# 856  guys program kampus merdeka bayar gasih studi independent ajar
#
#      label_id
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 852  1
# 853  1
# 854  1
# 855  1
# 856  1
#
# [857 rows x 7 columns]

# %% [markdown]
# # 13. Create variable y_new as array label and check the balance of data tweet

# %%
y_list = list(df_tweets['Label'])
y_new = np.array(y_list)

# %%
target_count = df_tweets['Label'].value_counts()
target_count.plot(kind='bar', title='Count (target)')
target_count
# Out:
# Mendukung          520
# Tidak Mendukung    337
# Name: Label, dtype: int64

# %%
X = df_tweets['preprocess_tweet'].values
y = df_tweets['Label'].values

# %% [markdown]
# # 14. TF-IDF & Word Visualization
# * TF-IDF adalah singkatan dari "Term Frequency – Inverse Document Frequency"
# * CountVectorizer: Menghitung setiap jumlah kata/corpus yang muncul dalam kumpulan data tersebut
# * Tfidf Transformer: Tranforming untuk perhitungan matriks dari CountVectorizer
# * Word Visualization: Menampilkan kata dengan ukuran font berdasarkan pembobotan TF-IDF

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X)
tfidf_transformer = TfidfTransformer()
Train_X_Tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
X_train_counts.shape
# Out:
# (857, 3037)

# %%
vectorizer = TfidfVectorizer(analyzer=lambda x: x, min_df=10)
token_vocab = df_tweets['tweet_norm2'].apply(word_tokenize_wrapper)
matrix = vectorizer.fit_transform([x for x in np.array(token_vocab)])
tfidf = dict(zip(vectorizer.get_feature_names_out(), vectorizer.idf_))
print ('vocab size :', len(tfidf))
# Out:
# vocab size : 129

# %%
def plot_word_cloud(terms):
    text = terms.index
    text = ' '.join(list(text))
    # lower max_font_size
    wordcloud = WordCloud(max_font_size=40).generate(text)
    plt.figure(figsize=(17, 17))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

tfidf2 = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf2.columns = ['tfidf']    
plot_word_cloud(tfidf2.sort_values(by=['tfidf'], ascending=True))

# %% [markdown]
# # 15. Data splitting for 20% data training & 80% data testing

# %% [markdown]
# ### Menggunakan teknik sampling SMOTE (Synthetic Minority Over-sampling Technique)
#
# Namun, karena dataset memiliki masalah ketidakseimbangan kelas, maka dilakukan oversampling pada data training menggunakan metode SMOTE. Setelah itu, model dibuat dan dilatih pada data training yang telah di-oversampling, dan kemudian digunakan untuk melakukan prediksi pada data testing.

# %%
from imblearn.over_sampling import SMOTE
train_pct_index = int(0.8 * len(X))
X_train, X_test = Train_X_Tfidf[:train_pct_index], Train_X_Tfidf[train_pct_index:]
y_train, y_test = y[:train_pct_index], y[train_pct_index:]
X_train, X_test, y_train, y_test = train_test_split(Train_X_Tfidf, y, test_size=0.2)
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # 16. Create & fitting model Naive Bayes

# %%
start_time = datetime.now()
mnb = MultinomialNB().fit(X_train_resampled, y_train_resampled)
y_pred2 = mnb.predict(X_test)
end_time = datetime.now()
print("Duration: {}".format(end_time - start_time))
# Out:
# Duration: 0:00:00.015592

# %% [markdown]
# # 17. Evaluation

# %%
from sklearn.metrics import f1_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from pandas import DataFrame

# print(confusion_matrix(y_test,y_pred2))
# print(classification_report(y_test,y_pred2))
print("Accuracy %.2f" % (accuracy_score(y_pred2, y_test) * 100 ))
print(metrics.classification_report(y_test, y_pred2, target_names=['Tidak Mendukung', 'Mendukung']))

columns = ['Tidak Mendukung', 'Mendukung']
confm = confusion_matrix(y_test, y_pred2)
df_cm = DataFrame(confm, index=columns, columns=columns)

ax = sn.heatmap(df_cm, cmap='Blues', annot=True)
ax.set_title('Confusion matrix')
ax.set_xlabel('Label prediksi')
ax.set_ylabel('Label sebenarnya')
# Out:
# Accuracy 83.14
#                  precision    recall  f1-score   support
#
# Tidak Mendukung       0.87      0.88      0.87       113
#       Mendukung       0.76      0.75      0.75        59
#
#        accuracy                           0.83       172
#       macro avg       0.81      0.81      0.81       172
#    weighted avg       0.83      0.83      0.83       172
# Text(50.72222222222221, 0.5, 'Label sebenarnya')

# %% [markdown]
# # 18. Prediction

# %% [markdown]
# ### Menggunakan smote

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd



stop_words = set(stopwords.words('indonesian'))
stop_words.add('kampus')
stop_words.add('merdeka')

test = input('Masukkan kalimat dalam bahasa Indonesia > ')
text = re.sub(r'[^\w\s]','', test)
text = text.encode('ascii', 'replace').decode('ascii')
text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
text = text.lower()

words = word_tokenize(text)
filtered_words = [word for word in words if word.casefold() not in stop_words]
text = ' '.join(filtered_words)

my_list_test = [text]
predicted = []

for i in my_list_test:
    a = count_vect.transform([i])
    X_coba = tfidf_transformer.fit_transform(a).toarray()
    y_pred = mnb.predict(X_coba)
    acc = mnb.predict_proba(X_coba)
    probmnb = acc.max(axis=1)
    pd.options.display.float_format = '{:,.2f}%'.format
    predicted.append({"tweet": test, "stopwords": i, "tokens": filtered_words, "label" : y_pred[0], "probability" : probmnb[0]*100})

pd.DataFrame(predicted)
# Out:
# Masukkan kalimat dalam bahasa Indonesia > Ikut studi independen seru, belajar dapat ilmu sekaligus uang juga...
#                                                                    tweet  \
# 0  Ikut studi independen seru, belajar dapat ilmu sekaligus uang juga...
#
#                                  stopwords  \
# 0  studi independen seru belajar ilmu uang
#
#                                            tokens      label  probability
# 0  [studi, independen, seru, belajar, ilmu, uang]  Mendukung 74.39%
